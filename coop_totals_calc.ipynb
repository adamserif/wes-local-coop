# %%
import pandas as pd
from openpyxl import Workbook
from openpyxl import load_workbook

# %%
share_prices = {
    "produce": 105.0,
    "meat": 50.0,
    "eggs": 28.0,
    "bread": 57.0,
    "dairy": 65.0,
    "cheese": 100.0,
    "preserves": 45.0,
    "coffee": 67.5,
    "tofu": 17.0, 
    "seitan": 29.0,
    "mushroom": 13.0
}

# %%
resp_df = pd.read_csv("s2020.csv")
# Cleanup data
resp_df = resp_df.drop(resp_df.columns[list(range(12))], axis=1).iloc[0:]

# %%
resp_df
# Out:
#                                                   V13  \
# 0   Please enter your group members' information (...
# 1                                          Zoe Kaplan
# 2                                        Samuel Linde
# 3                                        Eliza Samore
# 4                              Sivan Piatigorsky-Roth
# 5                                       Woanyen Mahn
# 6                                         Kevin Koech
# 7                                      Romina Beltran
# 8                                           Roby Mann
# 9                                   Yasmeen Alshabasy
# 10                                   Marc Longenecker
# 11                                         Emily Leff
# 12                                         Amy Geiger
# 13                                     Isabel Steckel
# 14                                      Clara Curbera
# 15                                         Abi Pipkin
# 16                                    Gabriel Ballard
# 17                                    Noah Lilienthal
# 18                                      Ellis Collier
# 19                                      Jessica Tyler
# 20                                       Annika Velez
# 21                                      Winona Murphy
# 22                                         Betsy Cole
#
#                                                   V14  \
# 0   Please enter your group members' information (...
# 1                                    Emily Chackerian
# 2                                   Caroline Bhupathi
# 3                                                 NaN
# 4                                                 NaN
# 5                                       Nick Richards
# 6                                         Sharine Foo
# 7                                       Rhea Aggarwal
# 8                                                 NaN
# 9                                        Ayana Dudley
# 10                                                NaN
# 11                                   Willis Weinstein
# 12                                      Sam Libberton
# 13                                                NaN
# 14                                   Stephanie Dukich
# 15                                    Gabriel Ballard
# 16                                         Abi Pipkin
# 17                                            Miranda
# 18                                       Elijah Comas
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V15  \
# 0   Please enter your group members' information (...
# 1                                   Alessandra Viegas
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                     Dario Highsmith
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                     Justin Ratkovic
# 10                                                NaN
# 11                                    Alexandra Sobor
# 12                                                NaN
# 13                                                NaN
# 14                                       Cade Sorgman
# 15                                      Miranda Hyman
# 16                                         Max Shatan
# 17                             Jack Canavan-Gosslelin
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V16  \
# 0   Please enter your group members' information (...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                    Elijah Blair-May
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                       Avery Kaplan
# 12                                                NaN
# 13                                                NaN
# 14                                     Emelia Gertner
# 15                              Jack Canavan-Gosselin
# 16                                    Stuart Woodhams
# 17                                     Josh Markowitz
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V17  \
# 0   Please enter your group members' information (...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                        Tajah Goode
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                        Annie Roach
# 16                                                NaN
# 17                                        Annie Roach
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V18  \
# 0   Please enter your group members' information (...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                    Noah Lilienthal
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V19  \
# 0   Please enter your group members' information (...
# 1                                zkaplan@wesleyan.edu
# 2                                 slinde@wesleyan.edu
# 3                                esamore@wesleyan.edu
# 4                           spiatigorsky@wesleyan.edu
# 5                                  wmahn@wesleyan.edu
# 6                                 kkoech@wesleyan.edu
# 7                               rbeltran@wesleyan.com
# 8                                  rmann@wesleyan.edu
# 9                             yalshabasy@wesleyan.edu
# 10                          mlongenecker@wesleyan.edu
# 11                                 eleff@wesleyan.edu
# 12                               ageiger@wesleyan.edu
# 13                              isteckel@wesleyan.edu
# 14                              ccurbera@wesleyan.edu
# 15                               apipkin@wesleyan.edu
# 16                              gballard@wesleyan.edu
# 17                           noahlilienthal@gmail.com
# 18                             eqcollier@wesleyan.edu
# 19                                jtyler@wesleyan.edu
# 20                               abvelez@wesleyan.edu
# 21                               wmurphy@wesleyan.edu
# 22                                edcole@wesleyan.edu
#
#                                                   V20  \
# 0   Please enter your group members' information (...
# 1                            echackerian@wesleyan.edu
# 2                              cbhupathi@wesleyan.edu
# 3                                                 NaN
# 4                                                 NaN
# 5                              Nrichards@wesleyan.edu
# 6                                   sfoo@wesleyan.edu
# 7                              raggarwal@wesleyan.edu
# 8                                                 NaN
# 9                                adudley@wesleyan.edu
# 10                                                NaN
# 11                            wweinstein@wesleyan.edu
# 12                            slibberton@wesleyan.edu
# 13                                                NaN
# 14                               sdukich@wesleyan.edu
# 15                              gballard@wesleyan.edu
# 16                               apipkin@wesleyan.edu
# 17                                mhyman@wesleyan.edu
# 18                                ecomas@wesleyan.edu
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V21  \
# 0   Please enter your group members' information (...
# 1                              aviegas01@wesleyan.edu
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                             Dhighsmith@wesleyan.edu
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                              jratkovic@wesleyan.edu
# 10                                                NaN
# 11                                asobor@wesleyan.edu
# 12                                                NaN
# 13                                                NaN
# 14                              csorgman@wesleyan.edu
# 15                                mhyman@wesleyan.edu
# 16                               mshatan@wesleyan.edu
# 17                       jackconavangoss@wesleyan.edu
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   V22  ...  \
# 0   Please enter your group members' information (...  ...
# 1                                                 NaN  ...
# 2                                                 NaN  ...
# 3                                                 NaN  ...
# 4                                                 NaN  ...
# 5                              Eblairmay@wesleyan.edu  ...
# 6                                                 NaN  ...
# 7                                                 NaN  ...
# 8                                                 NaN  ...
# 9                                                 NaN  ...
# 10                                                NaN  ...
# 11                               akaplan@wesleyan.edu  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                              egertner@wesleyan.edu  ...
# 15                          jcanavangoss@wesleyan.edu  ...
# 16                             swoodhams@wesleyan.edu  ...
# 17                            jmarkowitz@wesleyan.edu  ...
# 18                                                NaN  ...
# 19                                                NaN  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22                                                NaN  ...
#
#                                                  V181  \
# 0   If you're not splitting the price of this co-o...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                  V182  \
# 0   If you're not splitting the price of this co-o...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                  V183  \
# 0   If you're not splitting the price of this co-o...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                  V184  \
# 0   If you're not splitting the price of this co-o...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                  V185  \
# 0   By signing below, you agree that if any of you...
# 1   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 2   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 3   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 4   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 5   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 6   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 7   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 8   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 9   https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 10  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 11  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 12  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 13  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 14  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 15  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 16  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 17  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 18  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 19  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 20  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 21  https://wesleyan.co1.qualtrics.com/WRQualtrics...
# 22  https://wesleyan.co1.qualtrics.com/WRQualtrics...
#
#                                                  V186  LocationLatitude  \
# 0   Thank you for filling out this survey!  Once a...  LocationLatitude
# 1                                                   1   41.555694580078
# 2                                                   1    41.56379699707
# 3                                                   1    41.56379699707
# 4                                                   1    41.56379699707
# 5                                                   1   41.555603027344
# 6                                                   1   41.555603027344
# 7                                                   1   41.555603027344
# 8                                                   1   41.556503295898
# 9                                                   1   41.555603027344
# 10                                                  1   41.555694580078
# 11                                                  1   41.555603027344
# 12                                                  1   41.555603027344
# 13                                                  1    41.30810546875
# 14                                                  1   40.780899047852
# 15                                                  1   41.555603027344
# 16                                                  1    41.56379699707
# 17                                                  1   41.555603027344
# 18                                                  1   41.555603027344
# 19                                                  1   41.579803466797
# 20                                                  1   41.555603027344
# 21                                                  1   41.618698120117
# 22                                                  1   41.555603027344
#
#     LocationLongitude  LocationAccuracy Unnamed: 189
# 0   LocationLongitude  LocationAccuracy          NaN
# 1    -72.663200378418                -1          NaN
# 2    -72.646896362305                -1          NaN
# 3    -72.646896362305                -1          NaN
# 4    -72.646896362305                -1          NaN
# 5    -72.657600402832                -1          NaN
# 6    -72.657600402832                -1          NaN
# 7    -72.657600402832                -1          NaN
# 8       -72.658203125                -1          NaN
# 9    -72.657600402832                -1          NaN
# 10   -72.663200378418                -1          NaN
# 11   -72.657600402832                -1          NaN
# 12   -72.657600402832                -1          NaN
# 13   -72.927398681641                -1          NaN
# 14   -73.950202941895                -1          NaN
# 15   -72.657600402832                -1          NaN
# 16   -72.646896362305                -1          NaN
# 17   -72.657600402832                -1          NaN
# 18   -72.657600402832                -1          NaN
# 19   -72.500396728516                -1          NaN
# 20   -72.657600402832                -1          NaN
# 21             -72.75                -1          NaN
# 22   -72.657600402832                -1          NaN
#
# [23 rows x 178 columns]

# %%
wb = Workbook()
ws = wb.active
ws.title = "Shares by group"

totals = wb.create_sheet()
totals.title = "Individual totals"

contacts = wb.create_sheet()
contacts.title = "Contacts"

members = wb.create_sheet()
members.title = "Members of each Co-Op"
